# %% [markdown]
# ## Guide to deletion of warnings

# %% [markdown]
# ### Before
# ![Screenshot%202022-05-15%2022.58.51.png](attachment:Screenshot%202022-05-15%2022.58.51.png)

# %%
import warnings
warnings.filterwarnings("ignore")

# Introduce this code at the start or before warnings
# You may need to run the code twice to get result

# %% [markdown]
# ### After
# ![Screenshot%202022-05-15%2023.04.05.png](attachment:Screenshot%202022-05-15%2023.04.05.png)
